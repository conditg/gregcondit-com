# %%
import numpy as np
import pandas as pd

from bokeh.io import show, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import Label,ColumnDataSource, HoverTool
from bokeh.core.properties import value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
slots = ['Thinkful', 'vrsus', 'Daily Dose of Power','Accelerated Growth Advisors','Abbott Laboratories']
layers = ['-', 'Student', 'Data Analyst', 'Creator & Maintainer', 'Manager', 'Production Financial Analyst',
          'Commercial Financial Analyst','Product Cost Analyst','Corporate Financial Analyst','10K Reporting Analyst',
        'Founder & Analyst']


jobs = {'roles' : slots,
        '-'   :  [2018.6, 2017.7, 2017.55, 2016.25,2013],
        'Student':[.7, 0, 0, 0,0],
        'Data Analyst':   [0, 1.8, 0, 0,0],
        'Creator & Maintainer'  :  [0, 0, 2, 0,0],
        'Manager' :    [0,0,0,1.3,0],
        'Production Financial Analyst' : [0,0,0,0,.5],
        'Commercial Financial Analyst' : [0,0,0,0,.5],
        'Product Cost Analyst' : [0,0,0,0,.5],
        'Corporate Financial Analyst' : [0,0,0,0,.5],
        '10K Reporting Analyst' : [0,0,0,0,.25],
        'Founder & Analyst':    [0,0,0,0,1],
       }

       

co = ['Intensive Data Science & Machine Learning Certification',
         'SaaS Platform in the Legal Industry',
         'Educational Media Service',
         'Entrepreneurial Consulting Firm',
         'Biological Manufacturing',
         'Nutrition Sales & Marketing',
         'Singapore Supply Chain',
         'Sales Consolidation',
         'Investors Relations',
         'Abbott Shared Financial Services']

skills = ['Python, Mathematics, Predictive Methods, Deep Learning',
          'SQL (SSRS/Postgres), Report Building, Dashboarding & Analytics',
          'Concise Writing, Project Management',
          'Data Analysis & Forecasting, Project Management, Leadership',
          'Forecasting, Modelling',
          'Variance Analysis, Modelling',
          'Forecasting, Modelling, International Experience',
          'Data Management, Forecasting, Modelling',
          'Attention to Detail, Organization',
          'Attention to Detail, Project Management, Modelling'
         ]
  

p = figure(y_range=slots, plot_height=250,plot_width=800, x_range=(2013, 2019.5), title="Career Timeline - Hover for Info",
           toolbar_location=None,active_drag=None, active_scroll=None
          )

renderers = p.hbar_stack(layers, y='roles', height=.9,  source=ColumnDataSource(jobs), name=layers,
             color=['rgba(255,255,255,0)', 'rgba(199,92,220,1.0)', 'rgb(25,130,248)', 'grey', 'rgb(25,130,248)',
                    'rgb(25,130,248)', 'rgb(63,150,249)','rgba(101,171,250,1.0)', 'rgb(139,192,251)',
                    'rgb(177,212,252)', 'rgb(196,223,253)'],
             line_alpha=0,
            )
for i, r in enumerate(renderers[1:]):
    pos = r.name
    d = co[i]
    s = skills[i]
    hover = HoverTool(tooltips=[
        ("Role", "{} - {}".format(pos, d)),
        ("Skills", "{}".format(s))
    ], renderers=[r])
    p.add_tools(hover)

p.y_range.range_padding = 0
p.ygrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.yaxis.major_tick_line_color = None
p.xaxis.major_tick_line_color = 'grey'
p.xgrid.grid_line_color = 'grey'
p.outline_line_color = None
p.background_fill_color = '#2a2a2a'
p.border_fill_color = '#2a2a2a'

p.xaxis.axis_line_color = 'rgba(0,0,0,0)'
p.yaxis.axis_line_color = 'grey'
p.axis.major_label_text_color = 'white'
p.title.text_color = 'white'
p.title.align = 'center'

c = 2013.3
mtop = 1.33
ttop = 43.9

p.quad(top=[mtop+.2], bottom=[mtop-.97], left=[c-.15],
       right=[c+.9], color='#2a2a2a',
      line_color='grey', line_width=1, line_dash='solid')

key_employment = Label(x=c, y=ttop, x_units='data', y_units='screen',
                 text='Employment', render_mode='css', text_align='left',
                 text_color = 'white', text_font_size='8pt',
                 border_line_alpha=0, border_line_color = 'rgba(101,171,250,0)',
                 background_fill_color='rgba(101,171,250,0)')
p.add_layout(key_employment)

p.square(c-.065, mtop, size=6, color='rgb(25,130,248)')

key_edu = Label(x=c, y=ttop-15, x_units='data', y_units='screen',
                 text='Education', render_mode='css', text_align='left',
                 text_color = 'white',text_font_size='8pt',
                 border_line_alpha=0, border_line_color = 'rgba(199,92,220,0)',
                 background_fill_color='rgba(199,92,220,0)')
p.add_layout(key_edu)
p.square(c-.065, mtop-.38, size=6,  color='rgba(199,92,220,1)')


key_ent = Label(x=c, y=ttop-30, x_units='data', y_units='screen',
                 text='Entrepreneurship', render_mode='css', text_align='left',
                 text_color = 'white', text_font_size='8pt',
                 border_line_alpha=0, border_line_color = 'grey',
                 background_fill_alpha=0)
p.add_layout(key_ent)
p.square(c-.065, mtop-.76, size=6,  color='grey')

handle = show(p)
# Out:
#   <div class="bk-root" id="2e49ead8-07f1-4951-8813-1377e5e4145f" data-root-id="9516"></div>

# %%
from bokeh.embed import components, file_html
from bokeh.resources import CDN
script, div = components(p)

# %%
div
# Out:
# '\n<div class="bk-root" id="8158c8d2-c45f-4c93-a3f0-ce946e5cbf5c" data-root-id="9516"></div>'

# %%
script
# Out:
# '\n<script type="text/javascript">\n  (function() {\n    var fn = function() {\n      Bokeh.safely(function() {\n        (function(root) {\n          function embed_document(root) {\n            \n          var docs_json = \'{"fd43fdf0-8e94-4f2c-be55-59da0d4fd702":{"roots":{"references":[{"attributes":{"background_fill_color":{"value":"#2a2a2a"},"below":[{"id":"9526","type":"LinearAxis"}],"border_fill_color":{"value":"#2a2a2a"},"left":[{"id":"9531","type":"CategoricalAxis"}],"outline_line_color":{"value":null},"plot_height":250,"plot_width":800,"renderers":[{"id":"9526","type":"LinearAxis"},{"id":"9530","type":"Grid"},{"id":"9531","type":"CategoricalAxis"},{"id":"9534","type":"Grid"},{"id":"9543","type":"BoxAnnotation"},{"id":"9576","type":"GlyphRenderer"},{"id":"9581","type":"GlyphRenderer"},{"id":"9586","type":"GlyphRenderer"},{"id":"9591","type":"GlyphRenderer"},{"id":"9596","type":"GlyphRenderer"},{"id":"9601","type":"GlyphRenderer"},{"id":"9606","type":"GlyphRenderer"},{"id":"9611","type":"GlyphRenderer"},{"id":"9616","type":"GlyphRenderer"},{"id":"9621","type":"GlyphRenderer"},{"id":"9626","type":"GlyphRenderer"},{"id":"9651","type":"GlyphRenderer"},{"id":"9653","type":"Label"},{"id":"9657","type":"GlyphRenderer"},{"id":"9659","type":"Label"},{"id":"9663","type":"GlyphRenderer"},{"id":"9665","type":"Label"},{"id":"9669","type":"GlyphRenderer"}],"title":{"id":"9515","type":"Title"},"toolbar":{"id":"9541","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"9518","type":"Range1d"},"x_scale":{"id":"9522","type":"LinearScale"},"y_range":{"id":"9520","type":"FactorRange"},"y_scale":{"id":"9524","type":"CategoricalScale"}},"id":"9516","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"9536","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"9543","type":"BoxAnnotation"}},"id":"9537","type":"BoxZoomTool"},{"attributes":{},"id":"9538","type":"SaveTool"},{"attributes":{},"id":"9539","type":"ResetTool"},{"attributes":{},"id":"9540","type":"HelpTool"},{"attributes":{"active_drag":null,"active_inspect":"auto","active_multi":null,"active_scroll":null,"active_tap":"auto","tools":[{"id":"9535","type":"PanTool"},{"id":"9536","type":"WheelZoomTool"},{"id":"9537","type":"BoxZoomTool"},{"id":"9538","type":"SaveTool"},{"id":"9539","type":"ResetTool"},{"id":"9540","type":"HelpTool"},{"id":"9628","type":"HoverTool"},{"id":"9630","type":"HoverTool"},{"id":"9632","type":"HoverTool"},{"id":"9634","type":"HoverTool"},{"id":"9636","type":"HoverTool"},{"id":"9638","type":"HoverTool"},{"id":"9640","type":"HoverTool"},{"id":"9642","type":"HoverTool"},{"id":"9644","type":"HoverTool"},{"id":"9646","type":"HoverTool"}]},"id":"9541","type":"Toolbar"},{"attributes":{"fields":["-"]},"id":"9553","type":"Stack"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9543","type":"BoxAnnotation"},{"attributes":{"callback":null,"renderers":[{"id":"9596","type":"GlyphRenderer"}],"tooltips":[["Role","Manager - Entrepreneurial Consulting Firm"],["Skills","Data Analysis &amp; Forecasting, Project Management, Leadership"]]},"id":"9634","type":"HoverTool"},{"attributes":{"fields":["-","Student"]},"id":"9554","type":"Stack"},{"attributes":{"fields":["-","Student"]},"id":"9555","type":"Stack"},{"attributes":{"fields":["-","Student","Data Analyst"]},"id":"9556","type":"Stack"},{"attributes":{"fields":["-","Student","Data Analyst","Creator &amp; Maintainer","Manager","Production Financial Analyst","Commercial Financial Analyst","Product Cost Analyst"]},"id":"9567","type":"Stack"},{"attributes":{"fields":["-","Student","Data Analyst"]},"id":"9557","type":"Stack"},{"attributes":{"fields":["-","Student","Data Analyst","Creator &amp; Maintainer","Manager","Production Financial Analyst","Comme ...

# %%
html = file_html(p, CDN, "my plot")
len(html)
# Out:
# 30216
